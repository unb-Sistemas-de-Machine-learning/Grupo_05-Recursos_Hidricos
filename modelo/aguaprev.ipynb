# %%
››
# Out:
# >>> [1/7] Carregando e Normalizando Dados...
#    -> Correção aplicada: Média ajustada de 102935.9 para 102.9 metros.
#    -> Total de registros limpos: 34215
# >>> [2/7] Criando Features...
# >>> [3/7] Treinando Random Forest...
# >>> [4/7] Treinando XGBoost...
# >>> [5/7] Calculando Erros...
#
# --- RESULTADO DA REGRESSÃO ---
# MAE (Erro Médio Absoluto): 0.0008 metros
# Isso significa que o modelo erra, em média, 0.1 centímetros.
#
# >>> [6/7] Gerando Classificação de Risco...
# Limites definidos para o Teste:
#    [Normal]  Até 102.79m
#    [Atenção] De 102.79m até 102.88m
#    [Alerta]  Acima de 102.88m
#
# --- RELATÓRIO DE CLASSIFICAÇÃO ---
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.96      0.98       344
#      Atenção       0.96      0.98      0.97      1044
#       Alerta       1.00      1.00      1.00      5435
#
#     accuracy                           0.99      6823
#    macro avg       0.99      0.98      0.98      6823
# ...
